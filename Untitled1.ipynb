# %%
# Step 1: Libraries Import Karein
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import time

# Step 2: Dataset Load Karein (Built-in data, download ki zaroorat nahi!)
data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# Check karne ke liye ke 1000 se zyada records hain ya nahi
print("Total records/rows:", X.shape)

# Step 3: Data Preprocessing (Scaling & Train-Test Split)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Step 4: 3 Models Train aur Evaluate Karein
models = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42)
}

results = []

for name, model in models.items():
    # Training Time calculate karein
    start_time = time.time()
    model.fit(X_train, y_train)
    end_time = time.time()
    train_time = end_time - start_time

    # Predictions
    y_pred = model.predict(X_test)

    # Metrics
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results.append({
        "Model Name": name,
        "Training Time (sec)": round(train_time, 4),
        "Accuracy": round(acc, 4),
        "Precision": round(prec, 4),
        "Recall": round(rec, 4),
        "F1 Score": round(f1, 4)
    })

# Step 5: Comparison Table Print Karein
comparison_df = pd.DataFrame(results)
print("\n--- MODEL COMPARISON TABLE ---")
print(comparison_df)
# Out:
# Total records/rows: (569, 30)
#
# --- MODEL COMPARISON TABLE ---
#             Model Name  Training Time (sec)  Accuracy  Precision  Recall  \
# 0  Logistic Regression               0.0198    0.9737     0.9722  0.9859
# 1        Decision Tree               0.0200    0.9474     0.9577  0.9577
# 2        Random Forest               0.3165    0.9649     0.9589  0.9859
#
#    F1 Score
# 0    0.9790
# 1    0.9577
# 2    0.9722

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Random Forest ya kisi bhi model ka confusion matrix plot karne ke liye
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap="Blues")
plt.title("Confusion Matrix - Random Forest")
plt.show()

# %%
from google.colab import files

# Yahan 'Untitled.ipynb' ki jagah apni file ka naam likh dein (jo upar tab par likha ho)
files.download('Untitled.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5097/886312457.py in <cell line: 0>()
#       2
#       3 # Yahan 'Untitled.ipynb' ki jagah apni file ka naam likh dein (jo upar tab par likha ho)
# ----> 4 files.download('Untitled.ipynb')
#
# /usr/local/lib/python3.13/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: Untitled.ipynb
